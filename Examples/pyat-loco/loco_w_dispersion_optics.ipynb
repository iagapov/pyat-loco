# %% [markdown]
# ### NOTE
# If $\sum_{i} ||A||^2$ is the average of the squared error norm,This quantity can be written as $\frac{1}{n} ||A||^2$
# Where $||A||_F=\sqrt (\sum_{i}^m\sum_{j}^n A_{ij}^2) = \sqrt(Tr(A^{T}A))$
# ### LOCO(optics & dispersion)
# The parameters in the used model is varied by LOCO to minimize the $ \chi^2 $: deviation between the model and measured orbit response matrices $C_{model}$ and $C_{measured}$. Where $\sigma_i$ is the measured noise level on the ith BPM (variance of input error). And $W_i$ is the weights diagonal matrix $=\frac{1}{ \sigma^2_{i}}$.
#
#
# $$  \sum_{i} ||\epsilon||^2= \chi^2 = \chi^2_{orm} +  \chi^2_{disp} \Rightarrow \alpha_1 \chi^2_{orm} +  \alpha_2 \chi^2_{disp} $$
#
# $ \alpha_1 = 1, \alpha_2 = 0 , \alpha_3 = 0 \Rightarrow $ only optics corrections
# $ \alpha_1 = 0, \alpha_2 = 1, \alpha_3 = 0  \Rightarrow$ only dispersion corrections
# $ \alpha_1 = 0, \alpha_2 = 0, \alpha_3 = 1  \Rightarrow $optics and dispersion corrections
#
# Weighted Least Square Method
#
# $$  \chi^{2}_w =  \sum_{i} ((\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :]+ \alpha_3 \Delta C)-(\sum_{k}\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g_k}}  \Delta g_k + \sum_{k} \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g_k}}  \Delta g_k +\sum_{k} \alpha_3 \frac{\partial{C}}{\partial{g_k}}  \Delta g_k))^{2}W_{i}$$
#
# $$  \chi^{2}_w =   ((\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :]+ \alpha_3 \Delta C)-(\sum_{k}\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g_k}}  \Delta g_k + \sum_{k} \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g_k}}  \Delta g_k +\sum_{k} \alpha_3 \frac{\partial{C}}{\partial{g_k}}  \Delta g_k))^{T}W((\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :]+ \alpha_3 \Delta C)-(\sum_{k}\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g_k}}  \Delta g_k + \sum_{k} \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g_k}}  \Delta g_k  + \sum_{k} \alpha_3 \frac{\partial{C}}{\partial{g_k}}  \Delta g_k))$$
#
#
# $$  \chi^{2}_w =  (\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :] + \alpha_3 \Delta C)^T (\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :] + \alpha_3 \Delta C) W - (\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :] + \alpha_3 \Delta C)^T (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}}   +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}}+\alpha_3 \frac{\partial{C}}{\partial{g}}) W \Delta g
#
# -  (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}}  \Delta g +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} +  \alpha_3 \frac{\partial{C}}{\partial{g}})^T (\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :] + \alpha_3 \Delta C) W + (\Delta g^{T}\frac{\partial{C[0: -2, :]}^T}{\partial{g}}\frac{\partial{C[0: -2, :]}}{\partial{g}}\Delta g W\alpha_1)+ (\Delta g^{T}\frac{\partial{C[ -2 ::, :]}^T}{\partial{g}}\frac{\partial{C[ -2 ::, :]}}{\partial{g}}\Delta g W\alpha_2) + (\Delta g^{T}\frac{\partial{C}^T}{\partial{g}}\frac{\partial{C}}{\partial{g}}\Delta g W\alpha_3)$$
#
#
# $$ \frac{\partial{\chi^{2}_w}}{\partial{\Delta g}} = - 2 (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}}  \Delta g +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} +  \alpha_3 \frac{\partial{C}}{\partial{g}}) W (\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :] +  \alpha_3 \Delta C) + 2 (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}}  \Delta g +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} + \alpha_3 \frac{\partial{C}}{\partial{g}})^{T} W (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}}  \Delta g+  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} + \alpha_3 \frac{\partial{C}}{\partial{g}})\Delta g =0$$
#
# $$ (\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}} +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} +  \alpha_3 \frac{\partial{C}}{\partial{g}})^{T}(\alpha_1 \frac{\partial{C[0: -2, :]}}{\partial{g}} W \Delta g +  \alpha_2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} + \alpha_3 \frac{\partial{C}}{\partial{g}}) \Delta g= ( \alpha1 \frac{\partial{C[0: -2, :]}^{T}}{\partial{g}} + \alpha2 \frac{\partial{C[ -2 ::, :]}^{T}}{\partial{g}} + \alpha3 \frac{\partial{C}^{T}}{\partial{g}}) W(\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :]+  \alpha_3 \Delta C)$$
#
#
# $$  \Delta g =( (\alpha1 \frac{\partial{C[0: -2, :]}}{\partial{g}} ^{T}W\frac{\partial{C[0: -2, :]}}{\partial{g}})+(\alpha2 \frac{\partial{C[ -2 ::, :]}}{\partial{g}} ^{T}W\frac{\partial{C[ -2 ::, :]}}{\partial{g}}) + (\alpha3 \frac{\partial{C}}{\partial{g}} ^{T}W\frac{\partial{C}}{\partial{g}}))^{-1} ( \alpha1 \frac{\partial{C[0: -2, :]}^{T}}{\partial{g}} + \alpha2 \frac{\partial{C[ -2 ::, :]}^{T}}{\partial{g}} + \alpha3 \frac{\partial{C}^{T}}{\partial{g}}) W(\alpha_1 \Delta C[0: -2, :] + \alpha_2 \Delta C[ -2 ::, :]+ \alpha_3 \Delta C) $$
#
#
#
#
# Differences between the matrices arise from quadrupole gradient differences between the model and real storage ring as well as differences in the BPM gains and steering magnet calibrations. Therefore the gains and steerer calibrations are also fit in the χ2 minimization. The result is a model that best reproduces the measured response matrix. The model also accurately reproduces the beta functions, magnet gradients, BPM gains, and steering magnet calibrations of the real storage ring.

# %%
import at
print(f"LOCO, AT version")
from at import *
from pylab import *
from at_modules_w_eta import *
from at.load import load_mat
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from random import random
# Out:
# LOCO, AT version

# %%
#a =ndArray[0: -2, :]
#b = ndArray[ -2 ::, :]

# %%
# The lattice

from lattice import *
ring=at.Lattice(ring3, energy=1)
ring.radiation_off()

# %%
twiss = getOptics(ring, '*' )
make_plot(twiss, 'before errors')
# Out:
# preparing twiss ..
# Tunes=[0.39223152 0.39336109]
# Chrom=[-2.67735312 -1.96249018]

# %%
#ORM

Cxx, Cxy= ORM_x_eta_w(1.e-4, ring)
Cyy, Cyx= ORM_y_eta_w(1.e-4, ring)

print(shape(Cyx))
plotORM(Cxy)

#eta_xx, eta_yy= eta(1.e-4, ring)
# Out:
# (42, 40)

# %%
C0x, C0y, C0xy, C0yx, dCx, dCy, dCxy,dCyx  = generatingQuadsResponse_weta(ring, Cxx, Cyy,Cxy, Cyx )
#eta_0x, eta_0y, d_eta_x, d_eta_y = generatingQuadsResponse_eta(ring, eta_xx, eta_yy)
# Out:
# generating response to QF, n=19
# generating response to QS, n=19
# generating response to QD, n=19
# loading response to: QF
# loading response to: QS
# loading response to: QD

# %%
#Qs_strength

qs_indexes = get_refpts(ring, 'QS')
errorQS = 5.e-2
for i in range(len(qs_indexes)):
    ring[qs_indexes[i]].K = (errorQS * random())

# %%
## simulate_errors

errorQF = 72.e-3
errorQD = 52.e-3
tiltQF = 3.e-3
tiltQD = 3.e-3
#shiftQF = 3.e-5
#shiftQD = 3.e-5
errorQS =0
shiftQF = 0
shiftQD = 0
quads_info_error = simulateError(ring, errorQF, errorQD,errorQS, tiltQF, tiltQD, shiftQF, shiftQD)
twiss_error = getOptics(ring, '*')
make_plot(twiss_error, 'with errors')
# Out:
# simulating perturbed machine...
# preparing twiss ..
# Tunes=[0.42461334 0.42806935]
# Chrom=[-2.61841713 -2.16231797]

# %%
# ORM Cx, Cy

Cxx_err, Cxy_err= ORM_x_eta_w(1.e-4, ring)
Cyy_err, Cyx_err= ORM_y_eta_w(1.e-4, ring)

print(shape(Cxx_err))

plotORM(Cxy_err)



# DRM (dispersion responce matrix)

#eta_xx_err, eta_yy_err = eta(1.e-4, ring)
# Out:
# (42, 40)

# %%
bpm_indexes = get_refpts(ring, elements.Monitor)
n = len(bpm_indexes)
k = n+2
error_variance_vector = np.array([randint(1,100)] * n)
#error_variance_vector
error_variance= np.diag(error_variance_vector)
sigma_square = [i**2 for i in error_variance_vector]
w = [1/i for i in sigma_square]
W= np.diag(w)
W.shape

# W = (42, 40)
# Array to be added as row
row_to_be_added = np.array([randint(1,100)] * n)

# Adding row to numpy array
#W = np.vstack ((W, row_to_be_added) )
#W = np.vstack ((W, row_to_be_added) )

W.shape
# Out:
# (40, 40)

# %%
len(dCx)
# Out:
# 60

# %%
def defineMatrices_w_eta(W, alpha1, alpha2,alpha3, C0x, C0y, C0xy, C0yx, Cxx_err, Cyy_err, Cxy_err, Cyx_err, dCx, dCy, dCxy,dCyx):
    Nk = len(dCx)  # number of free parameters
    Nm = len(dCx) # number of measurements
    print('NK:', Nk)
    print('Nm:', Nm)

    Ax = np.zeros([Nk, Nk])
    Ay = np.zeros([Nk, Nk])
    Axy = np.zeros([Nk, Nk])
    Ayx = np.zeros([Nk, Nk])


    A = np.zeros([4 * Nk, Nk])

    ##

    Bx = np.zeros([Nk, 1])
    By = np.zeros([Nk, 1])
    Bxy = np.zeros([Nk, 1])
    Byx = np.zeros([Nk, 1])


    B = np.zeros([4 * Nk, 1])
    ##

    Dx = (Cxx_err[:, :] - C0x[:, :] )#- error_variance)  ### dk ?
    Dy = (Cyy_err[:, :] - C0y[:, :] )
    Dxy = (Cxy_err[:, :] - C0xy[:, :])
    Dyx = (Cyx_err[:, :] - C0yx[:, :] )


    ##

    for i in range(Nk):  ## i represents each quad
        # print('done A:', 100.* i ,'%')
        for j in range(Nk):
            Ax[i, j] = np.sum(np.dot(np.dot(dCx[i][0: -2, :],W*alpha1), dCx[j][0: -2, :].T)) + np.sum(np.dot(np.dot(dCx[i][ -2 ::, :],W*alpha2), dCx[j][ -2 ::, :].T)) + np.sum(np.dot(np.dot(dCx[i],W*alpha3), dCx[j].T))
            Ay[i, j] = np.sum(np.dot(np.dot(dCy[i][0: -2, :],W*alpha1), dCy[j][0: -2, :].T)) +  np.sum(np.dot(np.dot(dCy[i][ -2 ::, :],W*alpha2), dCy[j][ -2 ::, :].T))+ np.sum(np.dot(np.dot(dCy[i],W*alpha3), dCy[j].T))
            Axy[i, j] = np.sum(np.dot(np.dot(dCxy[i][0: -2, :],W*alpha1), dCxy[j][0: -2, :].T)) + np.sum(np.dot(np.dot(dCxy[i][ -2 ::, :],W*alpha2), dCxy[j][ -2 ::, :].T))+ np.sum(np.dot(np.dot(dCxy[i],W*alpha3), dCxy[j].T))
            Ayx[i, j] = np.sum(np.dot(np.dot(dCyx[i][0: -2, :],W*alpha1), dCyx[j][0: -2, :].T)) + np.sum(np.dot(np.dot(dCyx[i][ -2 ::, :],W*alpha2), dCyx[j][ -2 ::, :].T))+ np.sum(np.dot(np.dot(dCyx[i],W*alpha3), dCyx[j].T))
        A[i, :] = Ax[i, :]
        A[i + Nk, :] = Ay[i, :]
        A[i + 2 * Nk, :] = Axy[i, :]
        A[i + 3 * Nk, :] = Ayx[i, :]


    ##

    for i in range(Nk):
      #  Bx[i] = np.sum(np.dot(np.dot(alpha1*dCx[i][0: -2, :]+alpha2*dCx[i][ -2 ::, :],W), alpha1*Dx[0: -2, :].T+alpha2*Dx[ -2 ::, :].T))
       # By[i] = np.sum(np.dot(np.dot(alpha1*dCy[i][0: -2, :]+alpha2*dCy[i][ -2 ::, :],W), alpha1*Dy[0: -2, :].T+alpha2*Dy[ -2 ::, :].T))
        #Bxy[i] = np.sum(np.dot(np.dot(alpha1*dCxy[i][0: -2, :]+alpha2*dCxy[i][ -2 ::, :],W), alpha1*Dxy[0: -2, :].T+alpha2*Dxy[ -2 ::, :].T))
        #Byx[i] = np.sum(np.dot(np.dot(alpha1*dCyx[i][0: -2, :]+alpha2*dCyx[i][ -2 ::, :],W), alpha1*Dyx[0: -2, :].T+alpha2*Dyx[ -2 ::, :].T))

        Bx[i] = np.sum(np.dot(np.dot(dCx[i][0: -2, :],W*alpha1), Dx[0: -2, :].T))+  np.sum(np.dot(np.dot(dCx[i][ -2 ::, :],W*alpha2), Dx[ -2 ::, :].T)) + np.sum(np.dot(np.dot(dCx[i],W*alpha3), Dx.T))
        By[i] = np.sum(np.dot(np.dot(dCy[i][0: -2, :],W*alpha1), Dy[0: -2, :].T)) + np.sum(np.dot(np.dot(dCy[i][ -2 ::, :],W*alpha2), Dy[ -2 ::, :].T))+np.sum(np.dot(np.dot(dCy[i],W*alpha3), Dy.T))
        Bxy[i] = np.sum(np.dot(np.dot(dCxy[i][0: -2, :],W*alpha1), Dxy[0: -2, :].T))+ np.sum(np.dot(np.dot(dCxy[i][ -2 ::, :],W*alpha2), Dxy[ -2 ::, :].T))+np.sum(np.dot(np.dot(dCxy[i],W*alpha3), Dxy.T))
        Byx[i] = np.sum(np.dot(np.dot(dCyx[i][0: -2, :],W*alpha1), Dyx[0: -2, :].T))+ np.sum(np.dot(np.dot(dCyx[i][ -2 ::, :],W*alpha2), Dyx[ -2 ::, :].T))+np.sum(np.dot(np.dot(dCyx[i],W*alpha3), Dyx.T))


        B[i] = Bx[i]
        B[i + Nk] = By[i]
        B[i + 2 * Nk] = Bxy[i]
        B[i + 3 * Nk] = Byx[i]


    return A, B,

# %%
alpha1=0 #optics
alpha2=0 #dispersion
alpha3=1 #optics+dispersion
A,B = defineMatrices_w_eta(W, alpha1, alpha2,alpha3, C0x, C0y, C0xy, C0yx, Cxx_err, Cyy_err, Cxy_err, Cyx_err, dCx, dCy, dCxy,dCyx)
# Out:
# NK: 60
# Nm: 60

# %%
def getInverse(A, B,Nk, sCut):

    u, s, v = np.linalg.svd(A, full_matrices=True)

    smat = 0.0 * A
    si = s ** -1
    n_sv = sCut
    si[n_sv:] *= 0.0

    print("number of singular values {}".format(len(si)))
    smat[:Nk, :Nk] = np.diag(si)

    print('A' + str(A.shape), 'B' + str(B.shape), 'U' + str(u.shape), 'smat' + str(smat.shape), 'v' + str(v.shape))

    plt.plot(np.log(s), 'd--')
    plt.title('singular value')
    plt.show()

    plt.plot(si, 'd--')
    plt.title('singular value inverse')
    plt.show()

    Ai = np.dot(v.transpose(), np.dot(smat.transpose(), u.transpose()))

    ###
    r = (np.dot(Ai, B)).reshape(-1)
    plot(r, 'd')
    plt.show()

    # error
    e = np.dot(A, r).reshape(-1) - B.reshape(-1)
    plt.plot(e)
    plt.show()
    plt.plot(B)
    plt.show()

    return Ai, r, e

# %%
A
# Out:
# array([[1185915.28936385,  291397.36583409, -861343.6789672 , ...,
#         -515292.04309919, -209065.88990125,  516639.51108763],
#        [ 291397.36583409, 1185915.2897103 ,  291397.36622818, ...,
#          -57070.61551812, -515292.04312435, -209065.88979542],
#        [-861343.6789672 ,  291397.36622818, 1185915.28951446, ...,
#          386151.53381691,  -57070.61563027, -515292.04293379],
#        ...,
#        [-515133.39845317,  -57053.04401743,  386032.64849704, ...,
#          361550.76921294,   96422.14540163, -260220.7616726 ],
#        [-209001.52532507, -515133.3984784 ,  -57053.04412959, ...,
#           96422.14540163,  361550.76917108,   96422.14527592],
#        [ 516480.45099545, -209001.52521927, -515133.39828792, ...,
#         -260220.7616726 ,   96422.14527592,  361550.76894166]])

# %%
dk = len(dCx)
cut = 59
#AA= A+A_eta
#BB = B+B_eta
Ai, r, e_ = getInverse(A, B,dk, cut)
# Out:
# number of singular values 60
# A(240, 60) B(240, 1) U(240, 240) smat(240, 60) v(60, 60)

# %%
#A.shape
#A_eta

# %%
n_list = len(quads_info_error.s_pos)
quads_info = quad_info(ring)
quad_dict, quad_vals = getQuadFamilies(quads_info)
quads = [k for k in quad_dict.keys()]
quad_names = quads
setCorrection(ring, quads_info_error,quad_names, r , quads_info, n_list)
# Out:
# define correction : Done
# set correction : Done

# %%
twiss_corrected = getOptics(ring, '*')
make_plot(twiss, 'before errors')
make_plot(twiss_error, 'with errors')
make_plot(twiss_corrected, 'after corrections')
getBetaBeat(twiss, twiss_error)
getBetaBeat(twiss, twiss_corrected)
eta_xx_corr, eta_yy_corr= eta(1.e-4, ring)
Cxx_corr, Cxy_corr= ORM_x_eta_w(1.e-4, ring)
Cyy_corr, Cyx_corr= ORM_y_eta_w(1.e-4, ring)
compare_orm(Cxy, Cxy_err, Cxy_corr, 0)
#compare_drm(eta_xx, eta_xx_err, eta_xx_corr)
#compare_drm(eta_yy, eta_yy_err, eta_yy_corr)
#getDispersion(twiss, twiss_error, twiss_corrected)
# Out:
# preparing twiss ..
# Tunes=[0.41561947 0.39135414]
# Chrom=[-2.7029632  -1.98257587]
# getBetaBeat bx and by:
# Simulated beta beat, x:5.511102547211754%   y: 10.844655831198443%
# getBetaBeat bx and by:
# Simulated beta beat, x:0.4830807040328136%   y: 0.4722980929334119%
