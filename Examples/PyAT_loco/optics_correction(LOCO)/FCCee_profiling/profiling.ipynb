# %% [markdown]
# Wrote profile results to loco_simpleLattice_betaCorrection_qfqd.ipynb.lprof

# %%
import line_profiler

# %%
# !kernprof -l -o p_loco_fccee_100f4c_fixedErr.dat p_loco_fccee_100f4c_fixedErr.py
# Out:
# LOCO, AT version
# Figure(640x480)
# Execution time loading lattice: 17.863401412963867 sec
# Figure(640x480)
# getOptics: 1.9398255348205566 sec
# Choose Used correctors
# Total number of Correctors:  3324
# Number of used Correctors:  4
# Execution time choose correctors: 0.010970354080200195 sec
# Choose Used Quadrpoles Families
# # of QDG1: 36 # of QFG2: 40 # of QD1: 720 # of QF2: 720 # of QD3: 700 # of QF4: 696
# 102
# Execution time chose quadrpoles: 0.9554529190063477 sec
# Execution time ORMs: 15.555526971817017 sec
# orm dimensions:  (4, 3324)
# 0.0
# 0.0
# 1668.225515444474
# 45126.146525129116
# generating response to family  1
# Execution time: 15.204344749450684 sec
# generating response to family  2
# Execution time: 14.989137649536133 sec
# generating response to family  3
# Execution time: 15.006919860839844 sec
# generating response to family  4
# Execution time: 15.311148405075073 sec
# generating response to family  5
# Execution time: 15.100742101669312 sec
# ...

# %%
# !python -m line_profiler p_loco_fccee_100f4c_fixedErr.dat
# Out:
# Timer unit: 1e-06 s
#
# Total time: 16.677 s
# File: N:\musa\orbit_optics_github\optics_correction(LOCO)\Profiling\profiling5_simpleLattice_fccee_tests\FCCeett_example\profiling_at_modules_loco.py
# Function: getOptics at line 15
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     15                                           @profile
#     16                                           def getOptics(ring, refpts, bpm_random_noise):
#     17
#     18        12     177105.1  14758.8      1.1      elements_indexes = get_refpts(ring, refpts)
#     19        12   16499843.5 1374987.0     98.9      [elemdata0, beamdata, elemdata] = at.get_optics(ring, elements_indexes)
#     20        12         29.7      2.5      0.0      twiss = elemdata
#     21
#     22        12          5.0      0.4      0.0      return twiss
#
# Total time: 0.759628 s
# ...
